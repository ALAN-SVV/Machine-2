# %% [markdown]
# ### Instituto Superior Tecnologico Quito

# %% [markdown]
# ![jupyter](img/itq.png)

# %% [markdown]
# **Nombre:** Alan Velasco, Maiccol Zurita
#
# **Fecha:** 30/03/2026

# %%
# Creación aleatoria de datos
import numpy as np
X = np.array([0.5, 23, 0.3, 4.5, 0.3, 0.5,
              -28, -50, 60, -100, -10, -11, 13, 19, 1, 9])

# %%
# Medidas de tendencia central
from scipy import stats
media = np.mean(X)
mediana = np.median(X)
moda, _ = stats.mode(X)
print('media: ', media)
print('mediana: ', mediana)
print('moda :', moda)
# Out:
# media:  -4.24375
# mediana:  0.5
# moda : 0.3

# %%
# Medidas de posición
import numpy as np
import matplotlib.pyplot as plt

Q1 = np.percentile(X, 25)
Q3 = np.percentile(X, 75)
RIC = Q3 - Q1
lim_inf = Q1 - 1.5*RIC
lim_sup = Q3 + 1.5*RIC

print('RIC :', RIC)
print('limite inferior :', lim_inf)
print('limite superior :', lim_sup)
# Out:
# RIC : 20.25
# limite inferior : -40.625
# limite superior : 40.375

# %%
# Dibuja el diagrama de box and whiskers y determina visualmente el número de outliers
plt.boxplot(X)
plt.grid()
plt.title("Diagrama de caja y bigotes")
plt.show()

# %%
# Medidas de dispersión
desvest = np.std(X)
print('Desviación típica: ', desvest)
print('Varianza: ', desvest**2)
# Out:
# Desviación típica:  33.521242681880096
# Varianza:  1123.6737109375

# %%
# Medidas de distribución
asimetria = stats.skew(X)
curtosis = stats.kurtosis(X, fisher=True) # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kurtosis.html
print('Asimetría ', np.round(asimetria, 4))
print('Curtosis ', np.round(curtosis, 4))

if curtosis>0:
    print('Distribución Leptocúrtica')
elif curtosis<0:
    print('Distribución Platicúrtica')
else:
    print('Distribución Mesocúrtica')
# Out:
# Asimetría  -1.1302
# Curtosis  2.2858
# Distribución Leptocúrtica

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\Usuario\anaconda3\envs\machine2\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Usuario\anaconda3\envs\machine2\Lib\site-packages (from scikit-learn) (2.4.3)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Usuario\anaconda3\envs\machine2\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\Usuario\anaconda3\envs\machine2\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Usuario\anaconda3\envs\machine2\Lib\site-packages (from scikit-learn) (3.6.0)

# %%
# Cargar el set de datos de Iris
from sklearn import datasets
from pprint import pprint
iris = datasets.load_iris()
#pprint(iris)
X = iris.data
y = iris.target

# ¿Qué tipo de asimetría se observa en la variable "longitud del pétalo"?
#???

# ¿A qué tipo de distribución se ajusta la variable "ancho del sépalo", según su curtosis?
#???

# %%
# EJERCICIO EXTRA SOBRE EL DATASET DE IRIS
# Extraer la media y la desviación típica de cada variable en función de la clase y representarlo en un gráfico (plt.errorbar)
???
# Out:
# Object `?` not found.

# %% [markdown]
# El resultado debería ser algo como esto:
# <img src="images/errorbar.png">

# %%
import sklearn
print(sklearn.__file__)
# Out:
# C:\Users\Usuario\anaconda3\envs\machine2\Lib\site-packages\sklearn\__init__.py
